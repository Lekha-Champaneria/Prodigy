# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load data
df = pd.read_csv('/content/train.csv')

df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.describe().include='all'

# %%
# Example: Fill missing ages with the median age
df['Age'].fillna(df['Age'].median(), inplace=True)

# %%
# Survival Rate
df['Survived'].value_counts().plot(kind='bar')
plt.title('Survival Rate')
plt.show()

# %%
# Age Distribution
df['Age'].hist()
plt.title('Age Distribution')
plt.show()

# %%
# Gender and Survival
sns.barplot(x='Sex', y='Survived', data=df)
plt.title('Survival Rate by Gender')
plt.show()

# %%
# Class and Survival
sns.barplot(x='Pclass', y='Survived', data=df)
plt.title('Survival Rate by Class')
plt.show()

# %%
# Embarked Analysis
sns.barplot(x='Embarked', y='Survived', data=df)
plt.title('Survival Rate by Embarked')
plt.show()

# %%
# Survival by Age and Class
sns.scatterplot(x='Age', y='Survived', hue='Pclass', data=df)
plt.title('Survival by Age and Class')
plt.show()

# %%
# Survival by Gender and Class
sns.catplot(x='Pclass', hue='Sex', col='Survived', data=df, kind='count')
plt.title('Survival by Gender and Class')
plt.show()

# %%
# Load data
df2 = pd.read_csv('/content/test.csv')

df2.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Pclass       418 non-null    int64
#  2   Name         418 non-null    object
#  3   Sex          418 non-null    object
#  4   Age          332 non-null    float64
#  5   SibSp        418 non-null    int64
#  6   Parch        418 non-null    int64
#  7   Ticket       418 non-null    object
#  8   Fare         417 non-null    float64
#  9   Cabin        91 non-null     object
#  10  Embarked     418 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 36.0+ KB

# %%
df2.isnull().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
df2.describe().include='all'

# %%
# Example: Fill missing ages with the median age
df2['Age'].fillna(df['Age'].median(), inplace=True)

# %%
# Age Distribution
df2['Age'].hist()
plt.title('Age Distribution in Test Data')
plt.show()

# %%
# Fare Distribution
df2['Fare'].hist()
plt.title('Fare Distribution in Test Data')
plt.show()

# %%
# Gender Distribution
sns.countplot(x='Sex', data=df2)
plt.title('Gender Distribution in Test Data')
plt.show()

# %%
# Class Distribution
sns.countplot(x='Pclass', data=df2)
plt.title('Passenger Class Distribution in Test Data')
plt.show()

# %%
# Embarked Analysis
sns.countplot(x='Embarked', data=df2)
plt.title('Embarked Distribution in Test Data')
plt.show()

# %%
# Age vs. Fare
sns.scatterplot(x='Age', y='Fare', data=df2)
plt.title('Age vs. Fare in Test Data')
plt.show()

# %%
# Gender and Class Distribution
sns.catplot(x='Pclass', hue='Sex', data=df2, kind='count')
plt.title('Gender Distribution by Class in Test Data')
plt.show()
